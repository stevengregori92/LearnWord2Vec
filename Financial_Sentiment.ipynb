# %% [markdown]
# <a href="https://colab.research.google.com/github/stevengregori92/LearnWord2Vec/blob/main/Financial_Sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install umap-learn
import nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (0.5.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.10.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.5.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.65.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn) (67.7.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import os
import pandas as pd

from tqdm.auto import tqdm
from nltk.tokenize import word_tokenize
from gensim.models import FastText

# %% [markdown]
# #Prepare Corpus

# %%
# !gdown https://drive.google.com/uc?id=1oKcKWMyX4WZPNUo-tOhxn8mwkxaRxMqR
# !unzip /content/stock-market.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1oKcKWMyX4WZPNUo-tOhxn8mwkxaRxMqR
# To: /content/stock-market.zip
# 100% 206k/206k [00:00<00:00, 31.9MB/s]
# Archive:  /content/stock-market.zip
# replace stock_data.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
df = pd.read_csv('stock_data.csv')
df
# Out:
#                                                    Text  Sentiment
# 0     Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1     user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 2     user I'd be afraid to short AMZN - they are lo...          1
# 3                                     MNTA Over 12.00            1
# 4                                      OI  Over 21.37            1
# ...                                                 ...        ...
# 5786  Industry body CII said #discoms are likely to ...         -1
# 5787  #Gold prices slip below Rs 46,000 as #investor...         -1
# 5788  Workers at Bajaj Auto have agreed to a 10% wag...          1
# 5789  #Sharemarket LIVE: Sensex off day’s high, up 6...          1
# 5790  #Sensex, #Nifty climb off day's highs, still u...          1
#
# [5791 rows x 2 columns]

# %%
sentences = [word_tokenize(Text.lower()) for Text in tqdm(df.Text)]
sentences[:5]
# Out:
#   0%|          | 0/5791 [00:00<?, ?it/s]
# [['kickers',
#   'on',
#   'my',
#   'watchlist',
#   'xide',
#   'tit',
#   'soq',
#   'pnk',
#   'cpw',
#   'bpz',
#   'aj',
#   'trade',
#   'method',
#   '1',
#   'or',
#   'method',
#   '2',
#   ',',
#   'see',
#   'prev',
#   'posts'],
#  ['user',
#   ':',
#   'aap',
#   'movie',
#   '.',
#   '55',
#   '%',
#   'return',
#   'for',
#   'the',
#   'fea/geed',
#   'indicator',
#   'just',
#   '15',
#   'trades',
#   'for',
#   'the',
#   'year',
#   '.',
#   'awesome',
#   '.'],
#  ['user',
#   'i',
#   "'d",
#   'be',
#   'afraid',
#   'to',
#   'short',
#   'amzn',
#   '-',
#   'they',
#   'are',
#   'looking',
#   'like',
#   'a',
#   'near-monopoly',
#   'in',
#   'ebooks',
#   'and',
#   'infrastructure-as-a-service'],
#  ['mnta', 'over', '12.00'],
#  ['oi', 'over', '21.37']]

# %% [markdown]
# #Train FastText Model

# %%
model = FastText(sentences, vector_size=128, window=5, min_count=3, workers=4, epochs=1000, sg=0, hs=0)

# %% [markdown]
# #Save

# %%
os.makedirs("model/fasttext/", exist_ok=True)

# %%
model.save('model/fasttext/financial_statement.fasttext')

# %% [markdown]
# #Load

# %%
model = FastText.load('model/fasttext/financial_statement.fasttext')

# %% [markdown]
# #Model Information

# %%
fasttext = model.wv

# %%
fasttext.index_to_key
# Out:
# ['.',
#  ',',
#  'the',
#  'to',
#  ':',
#  'a',
#  'on',
#  'in',
#  'of',
#  'for',
#  'aap',
#  'and',
#  'is',
#  '!',
#  '-',
#  'https',
#  'user',
#  'it',
#  'i',
#  'at',
#  'this',
#  '%',
#  '?',
#  'short',
#  'up',
#  '...',
#  'will',
#  'from',
#  'with',
#  'over',
#  'here',
#  'today',
#  ')',
#  'be',
#  "'s",
#  '#',
#  'that',
#  'as',
#  'out',
#  'volume',
#  'day',
#  'are',
#  'like',
#  'but',
#  '(',
#  'long',
#  'if',
#  'now',
#  'not',
#  '&',
#  'you',
#  'has',
#  'good',
#  'stock',
#  'more',
#  'my',
#  'some',
#  'goog',
#  'above',
#  'new',
#  'bac',
#  'watch',
#  'stop',
#  'have',
#  'still',
#  'down',
#  'nice',
#  'we',
#  'back',
#  'buy',
#  'next',
#  'move',
#  'after',
#  'higher',
#  'by',
#  'off',
#  'coronavirus',
#  'so',
#  'just',
#  'see',
#  "n't",
#  'no',
#  'an',
#  'market',
#  'ong',
#  '....',
#  'one',
#  'sensex',
#  'triangle',
#  'was',
#  'time',
#  'week',
#  'or',
#  'trade',
#  'stocks',
#  'all',
#  'close',
#  'nifty',
#  'do',
#  ';',
#  'its',
#  'weekly',
#  'could',
#  '..',
#  '@',
#  'looking',
#  'break',
#  'big',
#  'support',
#  'breakout',
#  'go',
#  'again',
#  'going',
#  'nfx',
#  'bullish',
#  'last',
#  'looks',
#  'green',
#  'highs',
#  'target',
#  'points',
#  'what',
#  'lower',
#  'should',
#  'they',
#  'about',
#  'amzn',
#  'earnings',
#  'get',
#  'price',
#  'can',
#  'markets',
#  'high',
#  'position',
#  'into',
#  'rt',
#  'gap',
#  'may',
#  'below',
#  'under',
#  'when',
#  'since',
#  'would',
#  'line',
#  'me',
#  'low',
#  'amid',
#  'spy',
#  'resistance',
#  'too',
#  'strong',
#  'holding',
#  'sell',
#  'think',
#  '10',
#  'ddd',
#  'there',
#  'cash',
#  '2',
#  'well',
#  'trend',
#  'great',
#  'been',
#  'buying',
#  'p',
#  'shares',
#  'daily',
#  'list',
#  'take',
#  'calls',
#  'breaking',
#  'look',
#  '>',
#  'tomorrow',
#  'open',
#  'how',
#  'year',
#  '4',
#  'then',
#  '3',
#  'very',
#  'another',
#  'first',
#  'than',
#  "'m",
#  'gs',
#  'imo',
#  'flag',
#  'full',
#  '1',
#  'yesterday',
#  'did',
#  'coming',
#  'few',
#  'their',
#  '50',
#  'right',
#  'apple',
#  'trading',
#  'money',
#  'bought',
#  'entry',
#  'ed',
#  'level',
#  'your',
#  '20',
#  'soon',
#  'much',
#  's',
#  'why',
#  'global',
#  'am',
#  'run',
#  'profit',
#  'bank',
#  'march',
#  'puts',
#  'getting',
#  'days',
#  'street',
#  '5',
#  'oil',
#  'make',
#  'around',
#  'bounce',
#  'bottom',
#  'call',
#  'prices',
#  'investors',
#  'needs',
#  'top',
#  'cat',
#  'znga',
#  'before',
#  'hold',
#  'added',
#  'term',
#  'little',
#  'really',
#  'hit',
#  'news',
#  'vol',
#  'million',
#  'nkd',
#  'keep',
#  'also',
#  'any',
#  'taking',
#  'shot',
#  'bearish',
#  'v',
#  'red',
#  'these',
#  'pattern',
#  'gains',
#  'u.s.',
#  'ma',
#  'moving',
#  'come',
#  'trying',
#  'spx',
#  '30',
#  'tgt',
#  'bull',
#  'option',
#  'says',
#  'stops',
#  'small',
#  'play',
#  'start',
#  '=',
#  'action',
#  'setup',
#  'does',
#  'many',
#  'watching',
#  'pullback',
#  'aapl',
#  'had',
#  'jpm',
#  'got',
#  'near',
#  'friday',
#  'sold',
#  'upside',
#  'pay',
#  'only',
#  'better',
#  'years',
#  'goes',
#  'company',
#  'possible',
#  'likely',
#  'know',
#  'most',
#  'selling',
#  'macd',
#  'post',
#  'end',
#  '$',
#  'even',
#  'sales',
#  'ssys',
#  'loss',
#  'way',
#  '+',
#  'crisis',
#  'put',
#  'through',
#  'other',
#  'growth',
#  '6',
#  'swing',
#  'morning',
#  'broke',
#  'made',
#  'min',
#  'set',
#  'pandemic',
#  'share',
#  'might',
#  'who',
#  'two',
#  'feb',
#  'fb',
#  'gd',
#  'fs',
#  'drop',
#  'banks',
#  'bid',
#  'need',
#  'point',
#  'huge',
#  'de',
#  'want',
#  'us',
#  'scaling',
#  'jcp',
#  'continues',
#  'pop',
#  'our',
#  'making',
#  'fill',
#  'net',
#  'average',
#  'pdating',
#  'shorts',
#  'best',
#  'both',
#  'si',
#  '8',
#  'where',
#  'c',
#  'video',
#  'ready',
#  '2013',
#  'being',
#  'base',
#  'imho',
#  'say',
#  'test',
#  'channel',
#  'breaks',
#  'against',
#  'key',
#  'nvda',
#  'ooks',
#  'ng',
#  'major',
#  'far',
#  'rbi',
#  'same',
#  'profits',
#  '200',
#  'monthly',
#  'recent',
#  'cf',
#  'yhoo',
#  'mcp',
#  '1/2',
#  'wait',
#  'f',
#  'bby',
#  'msft',
#  'heard',
#  'early',
#  '500',
#  'those',
#  'es_f',
#  'interesting',
#  'gmc',
#  'lows',
#  'while',
#  'report',
#  'jan',
#  'bear',
#  'maybe',
#  'csn',
#  'companies',
#  'months',
#  'were',
#  'opens',
#  'consolidation',
#  'wants',
#  'fall',
#  'setting',
#  'done',
#  'hpq',
#  'billion',
#  'range',
#  'w/',
#  'love',
#  'intraday',
#  'flow',
#  'check',
#  'add',
#  'rs',
#  'trailing',
#  '7',
#  "'",
#  'lot',
#  'china',
#  'vs',
#  'people',
#  'cut',
#  'watchlist',
#  'sure',
#  'via',
#  'weeks',
#  'ooking',
#  'world',
#  'eps',
#  '15',
#  'which',
#  'ave',
#  'closed',
#  'dollar',
#  'took',
#  '1st',
#  'gold',
#  'fed',
#  'worst',
#  'anyone',
#  'demand',
#  'waiting',
#  'ebay',
#  'm',
#  'monday',
#  'fcx',
#  'rally',
#  'follow',
#  '100',
#  'solid',
#  'something',
#  'operational',
#  'risk',
#  'nicely',
#  '25',
#  'hard',
#  '9',
#  'gpn',
#  'economy',
#  'data',
#  'fund',
#  'away',
#  'them',
#  'prior',
#  'handle',
#  'almost',
#  'spw',
#  'area',
#  'value',
#  'he',
#  'wall',
#  '11',
#  'chk',
#  'cup',
#  'vng',
#  'thru',
#  'said',
#  'sv',
#  'marketupdates',
#  'o',
#  'signal',
#  'government',
#  '12',
#  'cs',
#  'potential',
#  'wmt',
#  'ago',
#  'financial',
#  'fast',
#  'thing',
#  'vxy',
#  'hope',
#  'beating',
#  'candle',
#  'wow',
#  'work',
#  'uptrend',
#  'weak',
#  'reversal',
#  'business',
#  'positive',
#  'cst',
#  'second',
#  'easy',
#  'dividend',
#  't',
#  'deck',
#  'push',
#  'pretty',
#  'starts',
#  'india',
#  'pcn',
#  '.....',
#  'qqq',
#  '--',
#  'fio',
#  'oi',
#  'ca',
#  'working',
#  'all-time',
#  'adding',
#  'cost',
#  'record',
#  'app',
#  'bit',
#  'yet',
#  'past',
#  'tight',
#  'including',
#  'probably',
#  'hot',
#  'sma',
#  'yes',
#  'hod',
#  'fib',
#  'h',
#  'squeeze',
#  'g',
#  'cm',
#  'options',
#  'until',
#  'economic',
#  'continue',
#  'because',
#  'always',
#  'decline',
#  'negative',
#  'ibm',
#  'levels',
#  'everyone',
#  'month',
#  'starting',
#  'between',
#  'already',
#  '13',
#  'mar',
#  'funds',
#  'side',
#  'opening',
#  'w',
#  'vs.',
#  'ms',
#  'went',
#  'never',
#  'buys',
#  'worth',
#  'due',
#  'having',
#  'cee',
#  'traders',
#  'downside',
#  'bad',
#  'mtg',
#  'till',
#  'swy',
#  'cheap',
#  'avg',
#  'gets',
#  'head',
#  'quick',
#  'once',
#  '60',
#  'every',
#  'swhc',
#  'wfc',
#  'apo',
#  'qcom',
#  'lockdown',
#  'stay',
#  'crore',
#  'april',
#  'ever',
#  'rising',
#  'jobs',
#  'ist',
#  'dip',
#  'idea',
#  'hits',
#  'lol',
#  'invn',
#  'es',
#  'falling',
#  'trades',
#  'losses',
#  'positions',
#  'per',
#  'pick',
#  'expected',
#  'shd',
#  'following',
#  "'ll",
#  'bet',
#  'quarter',
#  'heavy',
#  'clear',
#  '2012',
#  'eye',
#  'help',
#  'posted',
#  'finally',
#  'industry',
#  'large',
#  'double',
#  'x',
#  'interest',
#  'cross',
#  'dndn',
#  'oc',
#  'give',
#  'seems',
#  'debt',
#  'gevo',
#  'cover',
#  'portfolio',
#  'trendline',
#  'bar',
#  'overnight',
#  'let',
#  'rest',
#  'showing',
#  'momentum',
#  'retest',
#  'pt',
#  'triggered',
#  'during',
#  'turn',
#  'ema',
#  'trader',
#  'weakness',
#  'pull',
#  'half',
#  'ceo',
#  "'ve",
#  'hedge',
#  'oversold',
#  'beat',
#  'plan',
#  'late',
#  'current',
#  'falls',
#  'show',
#  'buyers',
#  'u',
#  'eod',
#  'closes',
#  'ends',
#  'dump',
#  '*',
#  'gain',
#  'beats',
#  'real',
#  'others',
#  'bulls',
#  'update',
#  'analysis',
#  'story',
#  'dvax',
#  'building',
#  'sbx',
#  'wo',
#  'na',
#  'comes',
#  'minutes',
#  'tc',
#  'split',
#  'covid-19',
#  'en',
#  'january',
#  'continuation',
#  'though',
#  'mon',
#  "'re",
#  'covered',
#  'biggest',
#  'xco',
#  'his',
#  'ana',
#  '40',
#  'gae',
#  'started',
#  'own',
#  'aa',
#  'step',
#  "'d",
#  'intc',
#  'se',
#  'aig',
#  'expect',
#  'straight',
#  'inflation',
#  'imm',
#  'lots',
#  'missed',
#  'sorry',
#  'game',
#  'times',
#  '18',
#  'additions',
#  'shorting',
#  'slow',
#  '3d',
#  'patience',
#  'consumer',
#  'free',
#  'ha',
#  'bvsn',
#  'ook',
#  'jump',
#  'dow',
#  'ahead',
#  '52',
#  'iphone',
#  'samsung',
#  'thursday',
#  'bears',
#  '450',
#  'lead',
#  'vmw',
#  'closing',
#  'oh',
#  'expectations',
#  'leg',
#  'mkt',
#  'gon',
#  'blog',
#  'overbought',
#  'note',
#  'lets',
#  'volatility',
#  'online',
#  'holds',
#  'nothing',
#  'gdx',
#  'size',
#  'cap',
#  'despite',
#  'held',
#  'less',
#  '435',
#  '<',
#  'try',
#  'div',
#  'enough',
#  'kos',
#  'left',
#  'tonight',
#  'tsa',
#  '400',
#  'divergence',
#  'surge',
#  'largest',
#  'doing',
#  'cuts',
#  'crude',
#  'ax',
#  'wrap',
#  'nem',
#  'rupee',
#  'failed',
#  'downtrend',
#  'group',
#  'europe',
#  'broken',
#  'headed',
#  'february',
#  'increase',
#  'deal',
#  '50sma',
#  'someone',
#  'dead',
#  'gmx',
#  'businesses',
#  'lockdowns',
#  'sector',
#  'correction',
#  'coh',
#  'technicals',
#  'dt',
#  'old',
#  '13for2013',
#  'rise',
#  'pos',
#  'mark',
#  'saying',
#  'night',
#  'seen',
#  'decent',
#  'box',
#  'least',
#  'gdp',
#  'sd',
#  '14',
#  'use',
#  'ow',
#  'results',
#  'mgm',
#  'governor',
#  '26',
#  'roll',
#  'reason',
#  'technical',
#  'ft',
#  'happens',
#  'return',
#  'dia',
#  '70',
#  'home',
#  'affy',
#  'e',
#  'setups',
#  'hate',
#  'wrong',
#  'nke',
#  'co',
#  'cloud',
#  'bonds',
#  'name',
#  'longs',
#  'wk',
#  'qco',
#  'rebound',
#  '80',
#  'change',
#  'thanks',
#  'n',
#  'b/o',
#  'later',
#  'everything',
#  '2011',
#  'yep',
#  'central',
#  'ceg',
#  '24',
#  'ove',
#  'federal',
#  'pphm',
#  'sk',
#  'radar',
#  'mean',
#  'book',
#  'makes',
#  'cmg',
#  'three',
#  'auto',
#  'q4',
#  'das',
#  'indicators',
#  'expiration',
#  'wsj',
#  'miss',
#  'sa',
#  'without',
#  'pin',
#  'kbh',
#  'traded',
#  'futures',
#  'rate',
#  'wynn',
#  'isis',
#  'lost',
#  'saudi',
#  '350',
#  '/',
#  'heading',
#  'confirming',
#  'byd',
#  'earlier',
#  '21',
#  'giving',
#  'cents',
#  'nearly',
#  'shows',
#  'ay',
#  'poised',
#  'short-term',
#  'ko',
#  'closely',
#  'retail',
#  'p/e',
#  'shaktikanta',
#  '430',
#  'gas',
#  'ocn',
#  'hes',
#  '425',
#  'expecting',
#  'pivot',
#  'called',
#  'upper',
#  'further',
#  'catch',
#  'pm',
#  'tell',
#  'hopes',
#  'float',
#  'eading',
#  'strength',
#  'csod',
#  'supply',
#  'estimates',
#  'american',
#  'believe',
#  '23',
#  'alert',
#  'spot',
#  'fight',
#  'must',
#  'tv',
#  'hours',
#  'turning',
#  'came',
#  'ngt',
#  'dnkn',
#  'po',
#  'either',
#  'et',
#  'hour',
#  'minute',
#  'compq',
#  'sellers',
#  'power',
#  'gme',
#  'fears',
#  'af',
#  '16',
#  'climb',
#  'numbers',
#  'hd',
#  '420',
#  'google',
#  'smart',
#  'based',
#  'dec',
#  'crazy',
#  'csco',
#  'along',
#  'acting',
#  'previous',
#  'confirmation',
#  'read',
#  'equity',
#  'hammer',
#  'vome',
#  'cen',
#  'kex',
#  'crash',
#  'anad',
#  'ok',
#  'targets',
#  'vhc',
#  'lose',
#  'sitting',
#  'create',
#  'stream',
#  'increased',
#  'drops',
#  'wedge',
#  'stake',
#  'ctic',
#  'panic',
#  'leading',
#  'seeing',
#  'invest',
#  'health',
#  'fdx',
#  'sharing',
#  'system',
#  '0',
#  'inside',
#  'filled',
#  '|',
#  'betting',
#  'within',
#  'vvs',
#  'bars',
#  'kwk',
#  'currently',
#  ...]

# %%
fasttext.vectors
# Out:
# array([[ 1.4296336 , -1.3984237 , -1.3092039 , ..., -0.34313765,
#          0.59211916,  2.5691922 ],
#        [-1.6349065 , -2.4268675 ,  1.8750215 , ..., -0.19044943,
#         -2.066842  ,  2.1274717 ],
#        [ 0.09221601, -0.10267656,  2.2214844 , ...,  0.44309106,
#          2.0613873 ,  0.8491145 ],
#        ...,
#        [-0.06407233, -2.0669057 , -2.9809477 , ..., -1.4433708 ,
#          1.2479845 , -1.5194942 ],
#        [ 0.03043609, -0.47189644,  0.49435937, ...,  0.6068292 ,
#          0.16924256,  2.6082683 ],
#        [-0.00414666, -0.3759518 ,  1.9122752 , ...,  1.6064292 ,
#         -3.1580055 ,  0.10691867]], dtype=float32)

# %%
fasttext.vector_size
# Out:
# 128

# %%
fasttext['like']
# Out:
# array([ 2.9218674 , -1.2368832 , -1.745289  ,  0.23669863,  4.051867  ,
#         2.2277646 ,  1.0276012 ,  3.412448  ,  0.36770007, -2.1418076 ,
#         2.7500014 ,  2.5693922 ,  0.8889851 ,  2.0212824 ,  2.4408553 ,
#         2.8243487 , -1.53605   ,  0.2709373 , -1.0164429 ,  2.238883  ,
#         0.31928083,  3.41229   , -4.019627  , -2.7521472 ,  2.522693  ,
#         4.456901  ,  0.20838545, -3.0237463 , -1.0642396 , -3.559357  ,
#         1.4130145 ,  1.4753456 , -0.80191714, -2.2517717 , -1.5980053 ,
#        -0.3120053 ,  1.3962473 , -4.1019135 , -0.09790934,  1.4266835 ,
#         1.5762168 ,  2.595643  , -2.242879  ,  0.60116005, -2.1719337 ,
#         0.43942878, -0.87141997, -1.4810735 , -3.1534727 ,  0.87419283,
#        -0.06062881, -6.3172045 , -3.0467188 ,  1.092666  , -3.6290987 ,
#         1.9120644 , -0.34927776,  2.6241014 , -0.22999547, -0.6672199 ,
#         0.38152555, -1.5476975 , -1.0260456 , -0.7975958 ,  1.9225408 ,
#        -0.7281983 , -0.60203207, -3.358653  ,  3.9328222 , -2.5355272 ,
#        -0.19334818,  2.183334  ,  1.6293788 , -2.738041  ,  0.5420452 ,
#        -2.7452178 , -3.7791305 ,  3.3004248 , -0.02393761,  0.3191908 ,
#         1.1445637 ,  1.16369   , -0.3194624 ,  4.067178  ,  4.8473682 ,
#        -2.689723  , -1.8796924 , -2.7265258 ,  1.197008  , -3.3995714 ,
#        -3.6861427 ,  0.56619334, -1.4955215 , -0.9167445 ,  2.6970212 ,
#        -2.6922047 ,  3.6829329 , -1.5709442 , -0.31003287,  2.4049234 ,
#        -0.7075114 ,  1.0110338 , -1.1646858 , -2.1932948 , -0.14621614,
#         2.5207555 ,  3.1315522 , -5.760841  ,  2.2242408 ,  4.0156674 ,
#        -0.83905274,  0.7193968 , -2.3796744 , -1.0701581 , -0.9545458 ,
#         0.23053855,  1.204065  ,  4.1222415 ,  1.2836438 , -3.4679346 ,
#         1.0893849 ,  0.5358009 ,  0.84879297, -0.50335586, -4.29384   ,
#        -2.3120134 ,  4.80286   , -0.30541003], dtype=float32)

# %% [markdown]
# #Sanity Check

# %% [markdown]
# similar word

# %%
fasttext.similar_by_word('stock', topn=5)
# Out:
# [('share', 0.3295898735523224),
#  ('right', 0.3203554153442383),
#  ('soon', 0.31961461901664734),
#  ('gone', 0.302438884973526),
#  ('that', 0.29957103729248047)]

# %% [markdown]
# higher order visualization

# %%
from umap import UMAP
import numpy as np
import pandas as pd
import plotly.express as px

# %%
X = UMAP().fit_transform(fasttext.vectors)

# %%
df = pd.DataFrame(X, columns = ['umap1', 'umap2'])
df['text'] = fasttext.index_to_key

# %%
df
# Out:
#          umap1     umap2       text
# 0     1.823165  2.746266          .
# 1     1.999296  2.827330          ,
# 2     2.000035  2.435148        the
# 3     1.863061  2.686481         to
# 4     3.943307  1.375477          :
# ...        ...       ...        ...
# 3267  4.595441 -0.449213  purchases
# 3268  1.146605  0.676178    doubled
# 3269  1.565851 -1.127857        ops
# 3270  1.093157 -2.184446         86
# 3271  4.292181 -0.443495       sebi
#
# [3272 rows x 3 columns]

# %%
fig = px.scatter(df, x='umap1', y='umap2', text='text')
fig.update_traces(textposition='top center')
fig.update_layout(
    height = 800,
    title_text = 'Reduced FastText Visualization'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ab79ad5e-8a91-488a-8465-4d97acd165b0" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab79ad5e-8a91-488a-8465-4d97acd165b0")) {                    Plotly.newPlot(                        "ab79ad5e-8a91-488a-8465-4d97acd165b0",                        [{"hovertemplate":"umap1=%{x}<br>umap2=%{y}<br>text=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","showlegend":false,"text":[".",",","the","to",":","a","on","in","of","for","aap","and","is","!","-","https","user","it","i","at","this","%","?","short","up","...","will","from","with","over","here","today",")","be","'s","#","that","as","out","volume","day","are","like","but","(","long","if","now","not","&","you","has","good","stock","more","my","some","goog","above","new","bac","watch","stop","have","still","down","nice","we","back","buy","next","move","after","higher","by","off","coronavirus","so","just","see","n't","no","an","market","ong","....","one","sensex","triangle","was","time","week","or","trade","stocks","all","close","nifty","do",";","its","weekly","could","..","@","looking","break","big","support","breakout","go","again","going","nfx","bullish","last","looks","green","highs","target","points","what","lower","should","they","about","amzn","earnings","get","price","can","markets","high","position","into","rt","gap","may","below","under","when","since","would","line","me","low","amid","spy","resistance","too","strong","holding","sell","think","10","ddd","there","cash","2","well","trend","great","been","buying","p","shares","daily","list","take","calls","breaking","look",">","tomorrow","open","how","year","4","then","3","very","another","first","than","'m","gs","imo","flag","full","1","yesterday","did","coming","few","their","50","right","apple","trading","money","bought","entry","ed","level","your","20","soon","much","s","why","global","am","run","profit","bank","march","puts","getting","days","street","5","oil","make","around","bounce","bottom","call","prices","investors","needs","top","cat","znga","before","hold","added","term","little","really","hit","news","vol","million","nkd","keep","also","any","taking","shot","bearish","v","red","these","pattern","gains","u.s.","ma","moving","come","trying","spx","30","tgt","bull","option","says","stops","small","play","start","=","action","setup","does","many","watching","pullback","aapl","had","jpm","got","near","friday","sold","upside","pay","only","better","years","goes","company","possible","likely","know","most","selling","macd","post","end","$","even","sales","ssys","loss","way","+","crisis","put","through","other","growth","6","swing","morning","broke","made","min","set","pandemic","share","might","who","two","feb","fb","gd","fs","drop","banks","bid","need","point","huge","de","want","us","scaling","jcp","continues","pop","our","making","fill","net","average","pdating","shorts","best","both","si","8","where","c","video","ready","2013","being","base","imho","say","test","channel","breaks","against","key","nvda","ooks","ng","major","far","rbi","same","profits","200","monthly","recent","cf","yhoo","mcp","1/2","wait","f","bby","msft","heard","early","500","those","es_f","interesting","gmc","lows","while","report","jan","bear","maybe","csn","companies","months","were","opens","consolidation","wants","fall","setting","done","hpq","billion","range","w/","love","intraday","flow","check","add","rs","trailing","7","'","lot","china","vs","people","cut","watchlist","sure","via","weeks","ooking","world","eps","15","which","ave","closed","dollar","took","1st","gold","fed","worst","anyone","demand","waiting","ebay","m","monday","fcx","rally","follow","100","solid","something"," ...
