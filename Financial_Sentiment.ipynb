# %% [markdown]
# <a href="https://colab.research.google.com/github/stevengregori92/LearnWord2Vec/blob/main/Financial_Sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install umap-learn
import nltk
nltk.download('punkt')
# Out:
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.10/dist-packages (0.5.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.10.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.56.4)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.5.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.65.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn) (67.7.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import os
import pandas as pd

from tqdm.auto import tqdm
from nltk.tokenize import word_tokenize
from gensim.models import FastText

# %% [markdown]
# #Prepare Corpus

# %%
# !gdown https://drive.google.com/uc?id=1EuL-mFDT5DEdW784MmTKdUfpq7mcQ5uD
# !unzip /content/financestate.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1EuL-mFDT5DEdW784MmTKdUfpq7mcQ5uD
# To: /content/financestate.zip
# 100% 282k/282k [00:00<00:00, 44.3MB/s]
# Archive:  /content/financestate.zip
#   inflating: data.csv

# %%
df = pd.read_csv('data.csv')
df
# Out:
#                                                Sentence Sentiment
# 0     The GeoSolutions technology will leverage Bene...  positive
# 1     $ESI on lows, down $1.50 to $2.50 BK a real po...  negative
# 2     For the last quarter of 2010 , Componenta 's n...  positive
# 3     According to the Finnish-Russian Chamber of Co...   neutral
# 4     The Swedish buyout firm has sold its remaining...   neutral
# ...                                                 ...       ...
# 5837  RISING costs have forced packaging producer Hu...  negative
# 5838  Nordic Walking was first used as a summer trai...   neutral
# 5839  According shipping company Viking Line , the E...   neutral
# 5840  In the building and home improvement trade , s...   neutral
# 5841  HELSINKI AFX - KCI Konecranes said it has won ...  positive
#
# [5842 rows x 2 columns]

# %%
sentences = [word_tokenize(Sentence.lower()) for Sentence in tqdm(df.Sentence)]
sentences[:5]
# Out:
#   0%|          | 0/5842 [00:00<?, ?it/s]
# [['the',
#   'geosolutions',
#   'technology',
#   'will',
#   'leverage',
#   'benefon',
#   "'s",
#   'gps',
#   'solutions',
#   'by',
#   'providing',
#   'location',
#   'based',
#   'search',
#   'technology',
#   ',',
#   'a',
#   'communities',
#   'platform',
#   ',',
#   'location',
#   'relevant',
#   'multimedia',
#   'content',
#   'and',
#   'a',
#   'new',
#   'and',
#   'powerful',
#   'commercial',
#   'model',
#   '.'],
#  ['$',
#   'esi',
#   'on',
#   'lows',
#   ',',
#   'down',
#   '$',
#   '1.50',
#   'to',
#   '$',
#   '2.50',
#   'bk',
#   'a',
#   'real',
#   'possibility'],
#  ['for',
#   'the',
#   'last',
#   'quarter',
#   'of',
#   '2010',
#   ',',
#   'componenta',
#   "'s",
#   'net',
#   'sales',
#   'doubled',
#   'to',
#   'eur131m',
#   'from',
#   'eur76m',
#   'for',
#   'the',
#   'same',
#   'period',
#   'a',
#   'year',
#   'earlier',
#   ',',
#   'while',
#   'it',
#   'moved',
#   'to',
#   'a',
#   'zero',
#   'pre-tax',
#   'profit',
#   'from',
#   'a',
#   'pre-tax',
#   'loss',
#   'of',
#   'eur7m',
#   '.'],
#  ['according',
#   'to',
#   'the',
#   'finnish-russian',
#   'chamber',
#   'of',
#   'commerce',
#   ',',
#   'all',
#   'the',
#   'major',
#   'construction',
#   'companies',
#   'of',
#   'finland',
#   'are',
#   'operating',
#   'in',
#   'russia',
#   '.'],
#  ['the',
#   'swedish',
#   'buyout',
#   'firm',
#   'has',
#   'sold',
#   'its',
#   'remaining',
#   '22.4',
#   'percent',
#   'stake',
#   ',',
#   'almost',
#   'eighteen',
#   'months',
#   'after',
#   'taking',
#   'the',
#   'company',
#   'public',
#   'in',
#   'finland',
#   '.']]

# %% [markdown]
# #Train FastText Model

# %%
model = FastText(sentences, vector_size=128, window=5, min_count=3, workers=4, epochs=1000, sg=0, hs=0)

# %% [markdown]
# #Save

# %%
os.makedirs("model/fasttext/", exist_ok=True)

# %%
model.save('model/fasttext/financial_statement.fasttext')

# %% [markdown]
# #Load

# %%
model = FastText.load('model/fasttext/financial_statement.fasttext')

# %% [markdown]
# #Model Information

# %%
fasttext = model.wv

# %%
fasttext.index_to_key
# Out:
# ['the',
#  '.',
#  ',',
#  'of',
#  'in',
#  'to',
#  'and',
#  'a',
#  '$',
#  'for',
#  'eur',
#  "'s",
#  'from',
#  'is',
#  'will',
#  'on',
#  'company',
#  'mn',
#  ':',
#  'its',
#  'as',
#  'by',
#  ')',
#  '%',
#  '(',
#  'with',
#  'profit',
#  'sales',
#  'has',
#  'be',
#  'at',
#  'finnish',
#  'said',
#  'net',
#  'it',
#  'million',
#  '``',
#  'that',
#  'was',
#  '-',
#  'operating',
#  '2009',
#  'mln',
#  '2008',
#  'period',
#  'year',
#  'group',
#  'finland',
#  'm',
#  'quarter',
#  'an',
#  'are',
#  '2007',
#  'share',
#  'new',
#  'up',
#  'oyj',
#  'business',
#  '2010',
#  'this',
#  'first',
#  'market',
#  'shares',
#  'loss',
#  'have',
#  'down',
#  'which',
#  'also',
#  'today',
#  'compared',
#  'services',
#  'euro',
#  '2006',
#  'helsinki',
#  'been',
#  'corresponding',
#  'about',
#  '&',
#  'per',
#  'operations',
#  'total',
#  'percent',
#  'contract',
#  'http',
#  'than',
#  'financial',
#  "'",
#  'price',
#  'https',
#  'decreased',
#  'after',
#  'not',
#  'bank',
#  'nokia',
#  'products',
#  'hel',
#  'were',
#  'stock',
#  'corporation',
#  'some',
#  '2005',
#  'we',
#  'more',
#  'according',
#  'pct',
#  'capital',
#  'or',
#  'production',
#  'over',
#  'increased',
#  'mobile',
#  'plant',
#  'other',
#  'companies',
#  'well',
#  'last',
#  'solutions',
#  '--',
#  'earlier',
#  'our',
#  'value',
#  'rose',
#  'technology',
#  'omx',
#  'investment',
#  'plc',
#  'all',
#  'result',
#  'their',
#  'now',
#  'unit',
#  'third',
#  'deal',
#  'would',
#  '@',
#  'fell',
#  'service',
#  'order',
#  'second',
#  'same',
#  'increase',
#  'construction',
#  'into',
#  'customers',
#  'board',
#  'had',
#  'building',
#  'ceo',
#  'billion',
#  'industry',
#  'aapl',
#  '10',
#  'part',
#  'half',
#  'out',
#  'expected',
#  'can',
#  'usd',
#  'earnings',
#  'oy',
#  'agreement',
#  'growth',
#  'long',
#  'maker',
#  'one',
#  'development',
#  'systems',
#  'lower',
#  'two',
#  'end',
#  'before',
#  'i',
#  'buy',
#  'media',
#  'markets',
#  'project',
#  'news',
#  'eur0',
#  'totalled',
#  'management',
#  'while',
#  'russia',
#  'report',
#  'under',
#  'time',
#  '#',
#  '...',
#  'months',
#  'paper',
#  'us',
#  'employees',
#  'equipment',
#  '1',
#  'september',
#  'area',
#  'may',
#  'exchange',
#  'revenue',
#  'approximately',
#  'global',
#  'annual',
#  'however',
#  'off',
#  'number',
#  'software',
#  'totaled',
#  'both',
#  'line',
#  '!',
#  'euros',
#  '2011',
#  'dividend',
#  'no',
#  'october',
#  'people',
#  'acquisition',
#  'data',
#  'march',
#  '20',
#  'tsla',
#  'stake',
#  'including',
#  'cash',
#  'between',
#  'sell',
#  'eps',
#  'they',
#  'oil',
#  'announced',
#  'steel',
#  'based',
#  'system',
#  'through',
#  'during',
#  'high',
#  'electronics',
#  'reported',
#  'short',
#  'manufacturing',
#  'these',
#  'expects',
#  'january',
#  'china',
#  '5',
#  '2',
#  'but',
#  'information',
#  'countries',
#  'due',
#  'day',
#  '?',
#  'estimated',
#  'manufacturer',
#  '3',
#  'amounted',
#  'support',
#  'sector',
#  'rights',
#  'higher',
#  'office',
#  'solution',
#  'when',
#  'start',
#  'further',
#  'he',
#  'use',
#  'signed',
#  'says',
#  'includes',
#  'made',
#  'nine',
#  'supply',
#  'engineering',
#  'reports',
#  'include',
#  'take',
#  'product',
#  'april',
#  'energy',
#  'items',
#  'design',
#  'largest',
#  'network',
#  'volume',
#  'most',
#  'since',
#  'next',
#  'years',
#  'sale',
#  'february',
#  '30',
#  ';',
#  'release',
#  'prices',
#  'transaction',
#  's',
#  'around',
#  'baltic',
#  'close',
#  '4',
#  '100',
#  'good',
#  '2004',
#  'here',
#  'very',
#  'back',
#  'president',
#  '`',
#  'pretax',
#  'above',
#  'communications',
#  'trade',
#  '6',
#  'nordic',
#  'world',
#  'position',
#  '.3',
#  'strong',
#  'international',
#  'still',
#  'ltd',
#  'target',
#  'if',
#  'units',
#  'local',
#  'august',
#  'fb',
#  'power',
#  'capacity',
#  'sweden',
#  'process',
#  'make',
#  'orders',
#  'offer',
#  'subsidiary',
#  'negotiations',
#  'such',
#  'staff',
#  'turnover',
#  'industrial',
#  'results',
#  'supplier',
#  'swedish',
#  'cost',
#  'networks',
#  'retail',
#  'major',
#  'available',
#  'year-on-year',
#  'non-recurring',
#  'currently',
#  'added',
#  'stora',
#  'three',
#  'elcoteq',
#  'ab',
#  'ruukki',
#  'option',
#  'costs',
#  'spy',
#  'scanfil',
#  'general',
#  'division',
#  '15',
#  'significant',
#  'chairman',
#  '25',
#  'excluding',
#  'uk',
#  'machinery',
#  'russian',
#  'following',
#  'move',
#  'previous',
#  'basware',
#  'directors',
#  'cent',
#  'yit',
#  'director',
#  'personnel',
#  'continue',
#  'fourth',
#  'level',
#  'nordea',
#  'shareholders',
#  'food',
#  'posted',
#  'plans',
#  'june',
#  'week',
#  'enso',
#  'issued',
#  'set',
#  'positive',
#  'there',
#  'november',
#  'where',
#  'traffic',
#  '50',
#  'phone',
#  'whole',
#  'insurance',
#  'projects',
#  'distribution',
#  'developed',
#  'security',
#  'situation',
#  'provider',
#  'won',
#  'real',
#  'margin',
#  'performance',
#  'already',
#  'see',
#  'fall',
#  'grew',
#  'via',
#  'research',
#  'plan',
#  'demand',
#  'meeting',
#  'cut',
#  'awarded',
#  'sold',
#  'related',
#  'like',
#  'customer',
#  'strategy',
#  'eur1',
#  'current',
#  'hit',
#  'issue',
#  '.9',
#  'range',
#  '.5',
#  'place',
#  'finnair',
#  'chain',
#  'index',
#  'completed',
#  'so',
#  'july',
#  'looking',
#  'europe',
#  'just',
#  'chief',
#  'own',
#  'america',
#  'fiskars',
#  '40',
#  'ftse',
#  'head',
#  'being',
#  'model',
#  'capman',
#  'adp',
#  'remain',
#  'north',
#  'tesco',
#  '..',
#  'near',
#  'agreed',
#  'estate',
#  'closed',
#  'taxes',
#  'income',
#  'center',
#  'ago',
#  'city',
#  'went',
#  'acquired',
#  'life',
#  'negative',
#  'addition',
#  '12',
#  '18',
#  'update',
#  '8',
#  'rise',
#  'flow',
#  'key',
#  'previously',
#  'developer',
#  'facility',
#  'handling',
#  'program',
#  'you',
#  'started',
#  'held',
#  'investors',
#  'joint',
#  'calls',
#  'mill',
#  'below',
#  'worth',
#  'astrazeneca',
#  'plants',
#  'only',
#  'terms',
#  'sports',
#  'daily',
#  'used',
#  'london',
#  'investments',
#  'inc.',
#  'internet',
#  'members',
#  'sampo',
#  'beer',
#  'any',
#  'interest',
#  'wednesday',
#  'petersburg',
#  'because',
#  'amount',
#  'delivered',
#  'alma',
#  'measures',
#  'sanoma',
#  '.6',
#  'estonia',
#  'focus',
#  'work',
#  'provides',
#  'processing',
#  'firm',
#  'who',
#  'germany',
#  'forest',
#  'my',
#  'voting',
#  '7',
#  'friday',
#  'european',
#  'small',
#  'aspo',
#  'large',
#  'press',
#  'x20ac',
#  'his',
#  'credit',
#  'provide',
#  'kemira',
#  'maintenance',
#  'low',
#  'several',
#  'packaging',
#  'am',
#  '17',
#  'marketing',
#  'bn',
#  'headquartered',
#  'thursday',
#  'applications',
#  'do',
#  'estimates',
#  'received',
#  'commercial',
#  'purchase',
#  'm-real',
#  '19',
#  'versus',
#  "n't",
#  'another',
#  'go',
#  '.1',
#  'water',
#  'cargotec',
#  'four',
#  'executive',
#  '22',
#  '11',
#  'trading',
#  'areas',
#  'published',
#  '31',
#  'monday',
#  'u.s.',
#  'holding',
#  'decided',
#  'metso',
#  'details',
#  'should',
#  'way',
#  'could',
#  'stockmann',
#  'yesterday',
#  'teliasonera',
#  'future',
#  'dropped',
#  'using',
#  'employs',
#  'lead',
#  'pay',
#  'rapala',
#  'takeover',
#  'okmetic',
#  'options',
#  'corp.',
#  'delivery',
#  'tuesday',
#  'declined',
#  'continuing',
#  'activities',
#  'store',
#  'poyry',
#  'afx',
#  'stocks',
#  'teleste',
#  'fixed',
#  '1.5',
#  'cooperation',
#  'long-term',
#  'bid',
#  'going',
#  'them',
#  '.8',
#  '.2',
#  'x',
#  'outlook',
#  'analyst',
#  'outotec',
#  'pharmaceutical',
#  'again',
#  'respectively',
#  'savings',
#  'aspocomp',
#  'december',
#  'slightly',
#  'combined',
#  'barclays',
#  'pulp',
#  'neste',
#  'public',
#  'corporate',
#  'partner',
#  'breakout',
#  'eur2',
#  'materials',
#  'points',
#  'fiscal',
#  'st.',
#  'rautaruukki',
#  'base',
#  'transfer',
#  'disclosed',
#  'full',
#  'technical',
#  'tonnes',
#  'stores',
#  'main',
#  'within',
#  'property',
#  'early',
#  'region',
#  '.4',
#  'konecranes',
#  'analysis',
#  'technologies',
#  'announcement',
#  'incap',
#  'q1',
#  'managing',
#  'standard',
#  'componenta',
#  'operates',
#  'looks',
#  'scheduled',
#  'liters',
#  'offers',
#  'right',
#  'device',
#  '9',
#  'potential',
#  'ahlstrom',
#  'what',
#  'maximum',
#  'government',
#  'bullish',
#  'built',
#  'telecom',
#  'aldata',
#  'shipping',
#  'printing',
#  'content',
#  'online',
#  'central',
#  'reporting',
#  'deliver',
#  'bought',
#  'subscription',
#  'provided',
#  'state',
#  'almost',
#  'strategic',
#  'mr',
#  'brand',
#  'properties',
#  '28',
#  'digital',
#  'gas',
#  'warning',
#  'making',
#  'cover',
#  'facilities',
#  'jobs',
#  'existing',
#  'application',
#  'deliveries',
#  'fund',
#  '23',
#  'big',
#  'offering',
#  'restructuring',
#  'funds',
#  'weak',
#  'glass',
#  'assets',
#  'poland',
#  '14',
#  'resistance',
#  'marimekko',
#  'expand',
#  'communication',
#  'nasdaq',
#  'representing',
#  'metal',
#  'chart',
#  'fair',
#  'starting',
#  'launch',
#  'merger',
#  'sabmiller',
#  'test',
#  'siemens',
#  'holdings',
#  'change',
#  'generated',
#  'told',
#  'glaston',
#  'included',
#  'tikkurila',
#  'businesses',
#  'continued',
#  'decision',
#  'operators',
#  'venture',
#  'owner',
#  'consumer',
#  'india',
#  'passenger',
#  'drug',
#  'planned',
#  'persons',
#  'resources',
#  'corp',
#  'established',
#  'administration',
#  'paid',
#  'infrastructure',
#  '29',
#  'record',
#  'improved',
#  'finland-based',
#  'national',
#  'square',
#  'get',
#  'manager',
#  'far',
#  'cargo',
#  'break',
#  'slipped',
#  'ready',
#  '2.7',
#  'kone',
#  'electronic',
#  'kesko',
#  'improve',
#  'changes',
#  'covers',
#  'broadband',
#  'did',
#  'consolidated',
#  'rental',
#  'factory',
#  'six',
#  'devices',
#  'contracts',
#  'competition',
#  'banks',
#  '26',
#  'effect',
#  'pohjola',
#  '1.2',
#  ',000',
#  '60',
#  'bridge',
#  'run',
#  'quality',
#  'logistics',
#  'providing',
#  'feb',
#  'consumers',
#  'video',
#  'much',
#  'nice',
#  'outokumpu',
#  'portfolio',
#  'raute',
#  'sq',
#  'b',
#  'approval',
#  'upm-kymmene',
#  'different',
#  'raw',
#  'adpnews',
#  '70',
#  '16',
#  'top',
#  'cramo',
#  'tesla',
#  'month',
#  'talvivaara',
#  'put',
#  'then',
#  'outside',
#  'atria',
#  'term',
#  'port',
#  'weeks',
#  'structures',
#  'hold',
#  'patent',
#  '27',
#  '200',
#  'continues',
#  'drop',
#  '21',
#  'beginning',
#  'become',
#  'apple',
#  'aim',
#  'material',
#  'team',
#  '3.5',
#  'upm',
#  'cencorp',
#  'handset',
#  'espoo',
#  'fortum',
#  'meat',
#  '1.1',
#  '2.5',
#  'subscribed',
#  '1.3',
#  'wood',
#  'return',
#  'sees',
#  'came',
#  'clients',
#  'rating',
#  'home',
#  'located',
#  'listed',
#  'brands',
#  'carried',
#  'gains',
#  'january-june',
#  'united',
#  'inbev',
#  'comptel',
#  'norway',
#  'recently',
#  'site',
#  'expansion',
#  'given',
#  'many',
#  'loan',
#  'got',
#  'ebit',
#  'great',
#  'mainly',
#  'phones',
#  'cuts',
#  'nyse',
#  'diluted',
#  'stood',
#  'invest',
#  'name',
#  'comparable',
#  '80',
#  'airline',
#  'operation',
#  'point',
#  'natural',
#  'look',
#  'narrowed',
#  'temporary',
#  'lines',
#  'segment',
#  'workers',
#  'growing',
#  'working',
#  'operational',
#  'those',
#  'responsible',
#  'january-september',
#  '2.2',
#  'aims',
#  'france',
#  'owns',
#  'date',
#  'passengers',
#  'rate',
#  'shareholder',
#  'getting',
#  'planning',
#  'owned',
#  'few',
#  'vaisala',
#  'union',
#  'biohit',
#  'bln',
#  '0.8',
#  'build',
#  'street',
#  'vice',
#  'signal',
#  'pension',
#  'american',
#  'tiimari',
#  'raised',
#  'morning',
#  'elisa',
#  'conditions',
#  'enables',
#  'royal',
#  'huhtamaki',
#  '13',
#  'enable',
#  'full-year',
#  'revenues',
#  'open',
#  'latest',
#  'interim',
#  'side',
#  'investor',
#  'm.',
#  'stockholm',
#  'debt',
#  'rt',
#  'profits',
#  'japan',
#  'ramirent',
#  'green',
#  'raisio',
#  'amzn',
#  'biggest',
#  'structure',
#  'needs',
#  'present',
#  'developing',
#  'space',
#  'states',
#  'norwegian',
#  'makes',
#  'decrease',
#  'your',
#  'music',
#  'five',
#  'nearly',
#  'sek',
#  'tekla',
#  'especially',
#  'volumes',
#  'rates',
#  'bounce',
#  'components',
#  'nflx',
#  'money',
#  'latvia',
#  'automation',
#  'metals',
#  'access',
#  'tons',
#  '0.3',
#  'lay',
#  'each',
#  'va.',
#  '4.5',
#  'register',
#  'summer',
#  'clothing',
#  'magazine',
#  'manufacture',
#  'improvement',
#  'department',
#  'talentum',
#  'electricity',
#  'complete',
#  ...]

# %%
fasttext.vectors
# Out:
# array([[-1.0714227 , -2.2012947 , -1.9817352 , ..., -2.4743857 ,
#         -0.36470795, -1.4184387 ],
#        [-0.355431  , -6.427335  ,  0.727478  , ..., -3.7376168 ,
#         -3.4074771 ,  3.8059816 ],
#        [ 0.25832182, -0.7992716 , -3.6261163 , ...,  1.1005619 ,
#          3.9355578 , -3.3237948 ],
#        ...,
#        [ 0.6017008 , -0.03448413, -0.7250042 , ...,  0.20424667,
#         -2.4761434 , -0.27073476],
#        [ 0.5172395 , -0.38770524,  0.5978345 , ...,  0.0508505 ,
#          2.9106903 , -2.1465216 ],
#        [-0.8700271 ,  0.97639614,  0.7007021 , ..., -0.99928135,
#          1.6020206 ,  2.548837  ]], dtype=float32)

# %%
fasttext.vector_size
# Out:
# 128

# %%
fasttext['like']
# Out:
# array([ 0.3136964 ,  5.8787856 , -6.2036834 ,  2.546511  ,  1.0859282 ,
#        -1.7338805 , -1.7615608 ,  2.5765593 ,  1.6584339 , -1.6802528 ,
#        -0.8779028 , -0.7239184 ,  5.8488445 , -2.6952622 , -2.8938384 ,
#         1.6921496 ,  0.37246504, -2.4540257 ,  2.711396  ,  1.9146622 ,
#        -4.7878423 ,  1.4132031 , -1.5026174 ,  2.584803  ,  4.067123  ,
#        -2.9498842 , -0.30850217,  0.48702174,  4.30045   , -1.719046  ,
#        -1.2731647 , -3.477218  ,  1.390945  ,  2.8240929 , -3.4971762 ,
#         1.3209589 ,  2.6548574 ,  3.677639  , -0.4438424 ,  4.6396747 ,
#         0.8793451 , -0.56036353, -2.1405    , -0.43562356,  3.1669817 ,
#        -3.494574  ,  1.3372118 , -1.8706849 , -0.19196905,  1.3033128 ,
#        -1.0966731 ,  5.846645  ,  1.985344  ,  1.2318231 , -2.4192235 ,
#        -0.93016535, -0.6761555 ,  1.5992036 , -4.4831815 , -6.840798  ,
#         2.6655574 ,  1.7699394 ,  3.5431032 , -0.9396446 ,  2.374645  ,
#         3.825817  , -0.92844105,  2.9541388 , -0.6518765 , -0.5118173 ,
#         2.5216372 ,  1.7310876 ,  0.8463823 , -0.7235002 ,  0.32606938,
#        -5.910539  , -2.363393  ,  1.3515369 , -2.1700742 , -5.427089  ,
#         4.5527334 ,  0.11797413, -2.7853124 ,  1.0019631 , -2.9192796 ,
#        -2.4256449 ,  3.9778762 ,  2.790013  ,  1.1408668 ,  0.8567184 ,
#         3.7614927 , -2.6854284 ,  1.0162177 ,  1.001736  ,  4.6555376 ,
#        -5.2071342 ,  0.5650912 ,  0.40806666, -1.7652097 , -5.0597234 ,
#         1.4330783 , -1.6757882 ,  4.34145   , -0.37984353, -0.7871942 ,
#        -2.8306346 ,  0.13064371, -2.8137527 , -3.250017  , -4.840366  ,
#        -0.1899985 ,  4.739701  ,  3.8548615 , -0.46047977,  0.15289679,
#         3.148329  , -1.0295132 , -2.635106  ,  1.7016238 ,  3.0399864 ,
#         5.3551993 ,  2.6029143 ,  3.4086792 ,  1.8964043 ,  3.3152268 ,
#         2.1412413 ,  5.177271  , -1.7422248 ], dtype=float32)

# %% [markdown]
# #Sanity Check

# %% [markdown]
# similar word

# %%
fasttext.similar_by_word('stock', topn=5)
# Out:
# [('stocks', 0.49626627564430237),
#  ('stockmann', 0.3519006669521332),
#  ('shares', 0.335403710603714),
#  ('block', 0.31194978952407837),
#  ('rights', 0.3076866567134857)]

# %% [markdown]
# higher order visualization

# %%
from umap import UMAP
import numpy as np
import pandas as pd
import plotly.express as px

# %%
X = UMAP().fit_transform(fasttext.vectors)

# %%
df = pd.DataFrame(X, columns = ['umap1', 'umap2'])
df['text'] = fasttext.index_to_key

# %%
df
# Out:
#          umap1      umap2       text
# 0     6.551000   8.315337        the
# 1     4.054900  12.177406          .
# 2     7.356484   7.338782          ,
# 3     5.165985   9.093748         of
# 4     5.451622   9.069100         in
# ...        ...        ...        ...
# 4104  2.168986  12.922604       20.9
# 4105  8.996648  11.118214      acg1v
# 4106  6.220226  10.227510       ride
# 4107  6.107831   9.600212    bounced
# 4108  6.401307  10.780334  catalysts
#
# [4109 rows x 3 columns]

# %%
fig = px.scatter(df, x='umap1', y='umap2', text='text')
fig.update_traces(textposition='top center')
fig.update_layout(
    height = 800,
    title_text = 'Reduced FastText Visualization'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ce18a375-05d8-4477-ac17-c2a2869b68e1" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ce18a375-05d8-4477-ac17-c2a2869b68e1")) {                    Plotly.newPlot(                        "ce18a375-05d8-4477-ac17-c2a2869b68e1",                        [{"hovertemplate":"umap1=%{x}<br>umap2=%{y}<br>text=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","showlegend":false,"text":["the",".",",","of","in","to","and","a","$","for","eur","'s","from","is","will","on","company","mn",":","its","as","by",")","%","(","with","profit","sales","has","be","at","finnish","said","net","it","million","``","that","was","-","operating","2009","mln","2008","period","year","group","finland","m","quarter","an","are","2007","share","new","up","oyj","business","2010","this","first","market","shares","loss","have","down","which","also","today","compared","services","euro","2006","helsinki","been","corresponding","about","&","per","operations","total","percent","contract","http","than","financial","'","price","https","decreased","after","not","bank","nokia","products","hel","were","stock","corporation","some","2005","we","more","according","pct","capital","or","production","over","increased","mobile","plant","other","companies","well","last","solutions","--","earlier","our","value","rose","technology","omx","investment","plc","all","result","their","now","unit","third","deal","would","@","fell","service","order","second","same","increase","construction","into","customers","board","had","building","ceo","billion","industry","aapl","10","part","half","out","expected","can","usd","earnings","oy","agreement","growth","long","maker","one","development","systems","lower","two","end","before","i","buy","media","markets","project","news","eur0","totalled","management","while","russia","report","under","time","#","...","months","paper","us","employees","equipment","1","september","area","may","exchange","revenue","approximately","global","annual","however","off","number","software","totaled","both","line","!","euros","2011","dividend","no","october","people","acquisition","data","march","20","tsla","stake","including","cash","between","sell","eps","they","oil","announced","steel","based","system","through","during","high","electronics","reported","short","manufacturing","these","expects","january","china","5","2","but","information","countries","due","day","?","estimated","manufacturer","3","amounted","support","sector","rights","higher","office","solution","when","start","further","he","use","signed","says","includes","made","nine","supply","engineering","reports","include","take","product","april","energy","items","design","largest","network","volume","most","since","next","years","sale","february","30",";","release","prices","transaction","s","around","baltic","close","4","100","good","2004","here","very","back","president","`","pretax","above","communications","trade","6","nordic","world","position",".3","strong","international","still","ltd","target","if","units","local","august","fb","power","capacity","sweden","process","make","orders","offer","subsidiary","negotiations","such","staff","turnover","industrial","results","supplier","swedish","cost","networks","retail","major","available","year-on-year","non-recurring","currently","added","stora","three","elcoteq","ab","ruukki","option","costs","spy","scanfil","general","division","15","significant","chairman","25","excluding","uk","machinery","russian","following","move","previous","basware","directors","cent","yit","director","personnel","continue","fourth","level","nordea","shareholders","food","posted","plans","june","week","enso","issued","set", ...
