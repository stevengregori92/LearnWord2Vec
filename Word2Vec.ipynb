# %% [markdown]
# <a href="https://colab.research.google.com/github/stevengregori92/LearnWord2Vec/blob/main/Word2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import os
import pandas as pd

from tqdm.auto import tqdm
from nltk.tokenize import word_tokenize
from gensim.models import Word2Vec

# %% [markdown]
# #Prepare Corpus

# %%
# !gdown https://drive.google.com/uc?id=10OnDq1OAByUxcQEPCDZ19jxU0W8QV6hu
# !unzip /content/word2vec.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10OnDq1OAByUxcQEPCDZ19jxU0W8QV6hu
# To: /content/word2vec.zip
# 100% 184k/184k [00:00<00:00, 84.2MB/s]
# Archive:  /content/word2vec.zip
#    creating: data/
#   inflating: data/kompas.txt
#    creating: __MACOSX/
#    creating: __MACOSX/data/
#   inflating: __MACOSX/data/._kompas.txt
#   inflating: data/.DS_Store
#   inflating: __MACOSX/data/._.DS_Store
#   inflating: data/gojek_review_sentiment.csv
#   inflating: __MACOSX/data/._gojek_review_sentiment.csv
#   inflating: data/gojek_review.csv

# %%
df = pd.read_csv('data/gojek_review.csv')
df.head()
# Out:
#                                               review  rate
# 0  Sangat kecewa. Kecewa sekali. Udh top up. Mau ...     1
# 1  Ga niat ngasih promo sialan temen udh pake ref...     1
# 2  Kalau sistemnya rata begini apa bedanya yg raj...     1
# 3  Ongkosnya da mahal, minimal 16rb..... Sekarang...     1
# 4  Tolol anjing..!!!! Aplikasi yang katanga karya...     1

# %%
sentences = [word_tokenize(review.lower()) for review in tqdm(df.review)]
sentences[:5]
# Out:
#   0%|          | 0/1277 [00:00<?, ?it/s]
# [['sangat',
#   'kecewa',
#   '.',
#   'kecewa',
#   'sekali',
#   '.',
#   'udh',
#   'top',
#   'up',
#   '.',
#   'mau',
#   'di',
#   'transaksi',
#   'in',
#   'malah',
#   'kasih',
#   'nomor',
#   'yang',
#   'salah',
#   '.',
#   'padahal',
#   'nomor',
#   'di',
#   'profil',
#   'benar',
#   '.',
#   'buat',
#   'ap',
#   'ah',
#   'q',
#   'top',
#   'up',
#   'tp',
#   'ga',
#   'bisa',
#   'digunain',
#   '.',
#   'balikin.',
#   '!',
#   'ga',
#   'becus',
#   '.',
#   'kasih',
#   'nomer',
#   'saalah',
#   '.',
#   'saya',
#   'mau',
#   'masukin',
#   'kode',
#   'transaksi',
#   'gimana.',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['ga',
#   'niat',
#   'ngasih',
#   'promo',
#   'sialan',
#   'temen',
#   'udh',
#   'pake',
#   'reff',
#   'ga',
#   'pake',
#   'cara',
#   'curang',
#   'malah',
#   'di',
#   'stop',
#   '.',
#   'kapitalis',
#   '.',
#   'daerah',
#   'ku',
#   'ongkir',
#   'ga',
#   'ada',
#   'subsidi',
#   'di',
#   'daerah',
#   'lain',
#   'masih',
#   'ada',
#   '.',
#   'ampas',
#   'gojek',
#   'skrng',
#   '.',
#   'strategi',
#   'baru',
#   'ga',
#   'bakar',
#   'duit',
#   'gimana',
#   '.',
#   'yg',
#   'ada',
#   'transaksi',
#   'hilang',
#   '2x',
#   'lipat',
#   '.',
#   'bukan',
#   'nambah',
#   '2x',
#   'lipat',
#   '.'],
#  ['kalau',
#   'sistemnya',
#   'rata',
#   'begini',
#   'apa',
#   'bedanya',
#   'yg',
#   'rajin',
#   '&',
#   'enggak',
#   '?',
#   'opang',
#   'ini',
#   'mah',
#   '.',
#   'kerja',
#   'lebih',
#   'lama',
#   'lagi',
#   '&',
#   'resiko',
#   'kecelakaan',
#   'pasti',
#   'lebih',
#   'tinggi',
#   '.',
#   'kapan',
#   'bonusnya',
#   'kalau',
#   'sejam',
#   'sekali',
#   'orderannya',
#   '.',
#   'ini',
#   'jakarta',
#   ',',
#   'males2',
#   'ya',
#   'ga',
#   'dapet',
#   'duit',
#   ',',
#   'kembalikan',
#   'sistem',
#   'sebelumnya',
#   'prioritas',
#   '!',
#   '!',
#   '!'],
#  ['ongkosnya',
#   'da',
#   'mahal',
#   ',',
#   'minimal',
#   '16rb',
#   '.....',
#   'sekarang',
#   'saya',
#   'beralih',
#   'ke',
#   'indriver',
#   ',',
#   'harga',
#   'masi',
#   'bisa',
#   'dapat',
#   '10-13rb',
#   'dengan',
#   'rute',
#   'jarak',
#   'sama',
#   ',',
#   'kalau',
#   'jarak',
#   'jauh',
#   'bs',
#   'selisih',
#   '10-15rb',
#   ',',
#   'dan',
#   'itu',
#   'murni',
#   'masuk',
#   'ke',
#   'driver',
#   'semua',
#   ',',
#   'di',
#   'gojek',
#   'bayar',
#   '16rb',
#   ',',
#   'driver',
#   'cm',
#   'dapat',
#   '8800',
#   ',',
#   'kasian',
#   'driver'],
#  ['tolol',
#   'anjing',
#   '..',
#   '!',
#   '!',
#   '!',
#   '!',
#   'aplikasi',
#   'yang',
#   'katanga',
#   'karya',
#   'anak',
#   'bangsa',
#   'tapi',
#   'kayak',
#   'kontol',
#   'gini',
#   '..',
#   '?',
#   '?',
#   '?',
#   'vocer',
#   'ditarik',
#   'lagi',
#   'bangsat',
#   '...',
#   '!',
#   '!',
#   '!',
#   '!',
#   'uninstall',
#   'gojek',
#   'lah',
#   ',',
#   'langganan',
#   'make',
#   'grab',
#   'wae',
#   '.',
#   'gojek',
#   'autis',
#   'sumpah',
#   ',',
#   'dasar',
#   'anjink',
#   'ceo',
#   'nya',
#   'kere',
#   '..',
#   '!',
#   '!',
#   '!',
#   '!',
#   'balikin',
#   'nadiem',
#   'aja',
#   'yang',
#   'jadi',
#   'ceo',
#   '...',
#   '!',
#   '!',
#   '!',
#   '!',
#   '>',
#   ':',
#   '(']]

# %% [markdown]
# #Train Word2Vec Model

# %%
model = Word2Vec(sentences, vector_size=128, window=5, min_count=3, workers=4, epochs=1000, sg=0, hs=0)

# %% [markdown]
# #Save

# %%
os.makedirs("model/w2v/", exist_ok=True)

# %%
model.save('model/w2v/gojek_review.w2v')

# %% [markdown]
# #Load

# %%
model = Word2Vec.load('model/w2v/gojek_review.w2v')

# %% [markdown]
# #Continue Training

# %%
contoh_data = [
    ['aplikasinya', 'ok', 'kok', '.', 'sangat', 'membantu', 'untuk', 'keseharian', 'saya'],
    ['aplikasinya', 'gak', 'nyaman', 'dipakai', 'bule']
]

# %%
model.train(contoh_data, total_examples = len(contoh_data), epochs=1)
# Out:
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# (10, 14)

# %%
model.save('model/w2v/gojek_review.w2v')

# %% [markdown]
# #Model Information

# %%
w2v = model.wv

# %%
w2v.index_to_key
# Out:
# [',',
#  '.',
#  'saya',
#  '!',
#  'di',
#  'gojek',
#  '..',
#  'yg',
#  'bisa',
#  '?',
#  'ada',
#  'nya',
#  'driver',
#  'dan',
#  'ini',
#  'aplikasi',
#  'tidak',
#  'yang',
#  'gak',
#  'mau',
#  'lagi',
#  'ga',
#  '...',
#  'tolong',
#  'aja',
#  'sudah',
#  'tapi',
#  'untuk',
#  'voucher',
#  'padahal',
#  'gopay',
#  'ke',
#  'sama',
#  'udah',
#  'order',
#  'lebih',
#  'akun',
#  'sangat',
#  'dengan',
#  'ya',
#  'buat',
#  'sekarang',
#  'kenapa',
#  'jadi',
#  'kasih',
#  'malah',
#  'lama',
#  'dari',
#  'gofood',
#  'itu',
#  'promo',
#  'kalo',
#  'jauh',
#  'juga',
#  'dapat',
#  'pake',
#  'karena',
#  'masuk',
#  'banyak',
#  'terus',
#  'kalau',
#  'apa',
#  'baru',
#  'go',
#  'dong',
#  'kok',
#  'gk',
#  'kecewa',
#  'pakai',
#  'selalu',
#  'harus',
#  'pesan',
#  'orderan',
#  'sistem',
#  'hari',
#  'cuma',
#  'makin',
#  'tp',
#  "''",
#  'saldo',
#  'banget',
#  'dulu',
#  'atau',
#  'anak',
#  'beli',
#  'sekali',
#  'mohon',
#  'sampai',
#  'makanan',
#  'sering',
#  'mahal',
#  'setiap',
#  'grab',
#  'masih',
#  'klo',
#  'pas',
#  'jangan',
#  'baik',
#  'saja',
#  '1',
#  'drivernya',
#  'sy',
#  'update',
#  'kali',
#  'membantu',
#  'perbaiki',
#  '(',
#  'semua',
#  'dapet',
#  'customer',
#  'orang',
#  'bintang',
#  'lah',
#  'goride',
#  'lain',
#  'kan',
#  'tdk',
#  'bikin',
#  'pesen',
#  'hp',
#  'sebelah',
#  'seperti',
#  'saat',
#  '....',
#  'masa',
#  'udh',
#  'top',
#  'karna',
#  'jelas',
#  'harga',
#  'kami',
#  'coba',
#  'up',
#  ')',
#  'gw',
#  'dalam',
#  'jam',
#  'bagus',
#  'kita',
#  'gimana',
#  'semakin',
#  'food',
#  'pelanggan',
#  'bayar',
#  'belum',
#  'sih',
#  'susah',
#  'aku',
#  'hanya',
#  'apk',
#  'pada',
#  '2',
#  'email',
#  'upgrade',
#  'd',
#  'pernah',
#  'bangsa',
#  'biar',
#  'terima',
#  'para',
#  'pihak',
#  'pesanan',
#  'dgn',
#  'gitu',
#  'parah',
#  'jd',
#  'pengguna',
#  'tau',
#  'suka',
#  'waktu',
#  'kasian',
#  'tetap',
#  'gini',
#  'login',
#  'salah',
#  'dpt',
#  'sdh',
#  'menggunakan',
#  'semoga',
#  'lg',
#  'kaya',
#  'sesuai',
#  'bukan',
#  'cancel',
#  'paylater',
#  'tarif',
#  'pindah',
#  'makan',
#  'gocar',
#  'terlalu',
#  'uang',
#  'mana',
#  'kurang',
#  'sendiri',
#  'jarak',
#  'sampe',
#  'lokasi',
#  'ganti',
#  'kode',
#  'ktp',
#  'nunggu',
#  'masalah',
#  'pembayaran',
#  'nih',
#  'akan',
#  'mending',
#  'vocer',
#  '``',
#  'punya',
#  'no',
#  'katanya',
#  'isi',
#  'tiap',
#  'g',
#  '5',
#  'layanan',
#  'pun',
#  'keluar',
#  'kalian',
#  'jg',
#  'mitra',
#  'naik',
#  'minta',
#  'nomor',
#  'ribet',
#  'biaya',
#  'diperbaiki',
#  'ngga',
#  'anda',
#  'kerja',
#  'karya',
#  'pasti',
#  'agar',
#  'tambah',
#  'tanpa',
#  'jalan',
#  'pulsa',
#  'terimakasih',
#  'diskon',
#  'cepat',
#  '3',
#  'nggak',
#  'langsung',
#  'cs',
#  'dr',
#  'kembali',
#  'resto',
#  'sebagai',
#  'tetep',
#  'bs',
#  'pin',
#  'enak',
#  'ilang',
#  'setelah',
#  ':',
#  'kasihan',
#  'skrg',
#  'ribu',
#  'indonesia',
#  'satu',
#  'tempat',
#  'dekat',
#  'eh',
#  'deh',
#  'mudah',
#  'knp',
#  'blm',
#  'tinggal',
#  'trus',
#  'poin',
#  'begini',
#  'jgn',
#  'hilang',
#  'murah',
#  'payah',
#  'kadang',
#  'respon',
#  'bagi',
#  'ketika',
#  'pelayanan',
#  'ternyata',
#  'fitur',
#  'kayak',
#  'beberapa',
#  'ngasih',
#  'minimal',
#  'sedikit',
#  'utk',
#  'transaksi',
#  'dia',
#  'pay',
#  'gua',
#  'apakah',
#  'eror',
#  'foto',
#  'app',
#  'min',
#  'ride',
#  'males',
#  'nama',
#  'hampir',
#  'error',
#  'dikasih',
#  'mengecewakan',
#  'niat',
#  'hujan',
#  'tiba',
#  'bulan',
#  'mereka',
#  'paket',
#  'maaf',
#  'konsumen',
#  'tujuan',
#  'si',
#  'sebelumnya',
#  'kirim',
#  'langganan',
#  'sukses',
#  'pembelian',
#  'cari',
#  'merugikan',
#  'hati',
#  'buruk',
#  'point',
#  'gue',
#  'jika',
#  'ko',
#  'merasa',
#  'biasa',
#  'sms',
#  'pt',
#  'rumah',
#  'butuh',
#  'menu',
#  'cukup',
#  'beda',
#  'mulu',
#  'buka',
#  'agak',
#  'segera',
#  'pemesanan',
#  'verifikasi',
#  'daftar',
#  'oleh',
#  'penumpang',
#  'kalah',
#  'benar',
#  'ingin',
#  'pelit',
#  'bgt',
#  'nadiem',
#  'ojol',
#  'lewat',
#  'online',
#  'tetapi',
#  'sya',
#  'titik',
#  'bener',
#  'jarang',
#  'doang',
#  'cuman',
#  '%',
#  'selama',
#  'ongkir',
#  'krn',
#  'ambil',
#  'tpi',
#  'bagaimana',
#  'digunakan',
#  'org',
#  'transportasi',
#  'sebelum',
#  'pilih',
#  'belanja',
#  'gagal',
#  'potongan',
#  'emang',
#  'biasanya',
#  'tahun',
#  'tak',
#  'deket',
#  '&',
#  'jek',
#  'setia',
#  'sedangkan',
#  'menjadi',
#  'besar',
#  'gojeknya',
#  'sistemnya',
#  'saran',
#  'perjalanan',
#  'gunakan',
#  'alamat',
#  'harusnya',
#  'dipakai',
#  'sepi',
#  'server',
#  'sedang',
#  'aplikasinya',
#  'memberikan',
#  'pilihan',
#  'membuat',
#  'cashback',
#  'otomatis',
#  'sulit',
#  'datang',
#  'dipake',
#  'bantuannya',
#  'gabisa',
#  'tiba2',
#  'dg',
#  'ulang',
#  'ny',
#  'ni',
#  'awal',
#  'hal',
#  '#',
#  'mencari',
#  'tolak',
#  'segala',
#  'muncul',
#  'tuh',
#  'kau',
#  'tagihan',
#  'adil',
#  'menunggu',
#  'menit',
#  'mobil',
#  'akhirnya',
#  'balik',
#  'rugi',
#  'mendapatkan',
#  'prioritas',
#  'kembalikan',
#  'gps',
#  'usah',
#  'jemput',
#  'suruh',
#  '10',
#  'voucer',
#  'system',
#  'aktif',
#  'bilang',
#  'pagi',
#  'berlaku',
#  'instal',
#  'jasa',
#  'data',
#  'sejak',
#  'mungkin',
#  'uninstall',
#  'dah',
#  'game',
#  'malam',
#  'uda',
#  'barang',
#  'semenjak',
#  'soalnya',
#  'ceo',
#  'disuruh',
#  'rating',
#  'nyaman',
#  'hapus',
#  'alasan',
#  'perlu',
#  '4',
#  'promonya',
#  'habis',
#  'chat',
#  'liat',
#  'bahkan',
#  'ramah',
#  'kepada',
#  'buru',
#  'mu',
#  'tetangga',
#  'ongkos',
#  'ad',
#  'restoran',
#  'nambah',
#  'keluarga',
#  'admin',
#  'ditarik',
#  'ngak',
#  'byk',
#  'tunai',
#  'proses',
#  'kota',
#  'kesini',
#  'pak',
#  'mantap',
#  'kantor',
#  'gosend',
#  'paling',
#  'terdekat',
#  'memesan',
#  'costumer',
#  'pke',
#  'motor',
#  'solusi',
#  'cara',
#  'kesel',
#  'lalu',
#  'duit',
#  'ku',
#  'ama',
#  'lbh',
#  'sekolah',
#  'apalagi',
#  'begitu',
#  'akhir',
#  'melakukan',
#  'berkali',
#  'posisi',
#  'jdi',
#  'bank',
#  'lainnya',
#  'uninstal',
#  'tarik',
#  'sehari',
#  'baca',
#  'dlu',
#  'atm',
#  'bonus',
#  'transfer',
#  'makasih',
#  'otp',
#  'memberi',
#  'maju',
#  'senang',
#  'gx',
#  'go-jek',
#  'bekukan',
#  'apaan',
#  '.....',
#  'tunggu',
#  'apapun',
#  'enggak',
#  'main',
#  'namanya',
#  'versi',
#  'dri',
#  'tarifnya',
#  'vouchernya',
#  'anjing',
#  'n',
#  'maps',
#  'terjadi',
#  'alhamdulillah',
#  'tulisan',
#  'mulai',
#  'gmn',
#  'google',
#  'tindak',
#  'luar',
#  'atas',
#  'vocher',
#  'pengen',
#  'pertama',
#  'demi',
#  '*',
#  'in',
#  'berat',
#  'token',
#  'rb',
#  'masak',
#  '2020',
#  'oke',
#  'harganya',
#  'bermanfaat',
#  'kasi',
#  'it',
#  'telpon',
#  'minggu',
#  'tadi',
#  'pergi',
#  'sebenarnya',
#  'keterangan',
#  'lihat',
#  'cepet',
#  'malas',
#  'bos',
#  'sm',
#  'msh',
#  'jadinya',
#  'skrng',
#  'log',
#  'gratis',
#  'sayang',
#  'jelek',
#  'mesen',
#  'lu',
#  'masukan',
#  'jawab',
#  'adanya',
#  'dll',
#  'berubah',
#  'gila',
#  'memuaskan',
#  'terbaru',
#  'kaga',
#  'tlp',
#  'rusak',
#  'guna',
#  'sibuk',
#  'kemana',
#  'terakhir',
#  'dimana',
#  'penjelasan',
#  'seharusnya',
#  'telepon',
#  'sim',
#  'sungguh',
#  'sengaja',
#  'memang',
#  'via',
#  'an',
#  'terdaftar',
#  'pemberitahuan',
#  'supaya',
#  'yah',
#  'bangkrut',
#  'bsa',
#  'percuma',
#  'walaupun',
#  'mendapat',
#  'memakai',
#  '30',
#  'parkir',
#  'telat',
#  'kendaraan',
#  'rajin',
#  'mah',
#  'narik',
#  'cash',
#  'ojek',
#  'dikit',
#  'lancar',
#  'tolol',
#  'tinggi',
#  'terbantu',
#  'antar',
#  'trimakasih',
#  'berkurang',
#  'x',
#  'km',
#  'anyep',
#  'jauh2',
#  'id',
#  'kl',
#  'boleh',
#  'adalah',
#  'terpotong',
#  'benerin',
#  'nyari',
#  'pdhl',
#  'aneh',
#  'sinyal',
#  'anyeb',
#  'rekening',
#  'semangat',
#  'kedepannya',
#  'nanti',
#  'sopan',
#  'putih',
#  'telah',
#  'berulang',
#  'da',
#  'pokoknya',
#  'sehingga',
#  'depan',
#  'lo',
#  '50',
#  'tingkatkan',
#  'kendala',
#  '7',
#  'siapa',
#  'hubungi',
#  'kapan',
#  'tgl',
#  'nomer',
#  '+',
#  'pulang',
#  '/',
#  'notif',
#  'allah',
#  'tiba-tiba',
#  'kuota',
#  'hrs',
#  'k',
#  'sumpah',
#  'hidup',
#  'bermasalah',
#  'rute',
#  'caranya',
#  'gi',
#  'minimum',
#  '-',
#  'y',
#  'gede',
#  'secara',
#  'pelayanannya',
#  'saldonya',
#  'siap',
#  'melalui',
#  'dibilang',
#  'kamu',
#  'kagak',
#  'penjemputan',
#  'tlg',
#  'wajah',
#  'potong',
#  'beralih',
#  'penipuan',
#  'ketentuan',
#  'takut',
#  'temen',
#  'tu',
#  'tepat',
#  'event',
#  'lupa',
#  'ubah',
#  'semuanya',
#  'buang',
#  'tanya',
#  'akal',
#  'topup',
#  'ok',
#  '10rb',
#  'memudahkan',
#  'driver2',
#  'daerah',
#  'repot',
#  'la',
#  'diri',
#  'make',
#  'permintaan',
#  'go-ride',
#  'smua',
#  'ongkirnya',
#  'kebanyakan',
#  'bener2',
#  'penting',
#  'thanks',
#  'menerima',
#  'muter',
#  'trs',
#  'bobrok',
#  'terhadap',
#  'berapa',
#  'car',
#  'keadaan',
#  'gofoodnya',
#  'gacor',
#  'halo',
#  'slalu',
#  'bawa',
#  'bnyak',
#  'tanggal',
#  'bensin',
#  'cek',
#  'download',
#  'goshop',
#  'gara',
#  'mempermudah',
#  'klik',
#  'ngk',
#  'pemerataan',
#  '20',
#  'teman',
#  'kena',
#  'mikir',
#  'tutup',
#  'sore',
#  'utama',
#  'resiko',
#  'kedua',
#  'seminggu',
#  'sma',
#  'toko',
#  'hemat',
#  '25k',
#  'bangsat',
#  'padat',
#  'pdhal',
#  'khusus',
#  'membeli',
#  'jaraknya',
#  'menarik',
#  'nominal',
#  'buram',
#  'per',
#  'jln',
#  'solusinya',
#  'malu',
#  'syarat',
#  'terutama',
#  'kemarin',
#  'seenak',
#  'melulu',
#  'koq',
#  'dana',
#  'iya',
#  'bertambah',
#  'keamanan',
#  'kata',
#  'lumayan',
#  'diambil',
#  'layar',
#  'map',
#  'pakek',
#  'memilih',
#  'nmr',
#  'hai',
#  'batalin',
#  'diamond',
#  'masyarakat',
#  'gagu',
#  'kek',
#  'berkah',
#  'tersebut',
#  'internet',
#  'masukin',
#  'pribadi',
#  'beri',
#  'sebesar',
#  'nggk',
#  'fasilitas',
#  'hangus',
#  'telp',
#  'disaat',
#  'spt',
#  'kebutuhan',
#  'pemilik',
#  'tambahkan',
#  'percaya',
#  'halal',
#  'gojeg',
#  'apl',
#  'good',
#  'namun',
#  'antara',
#  'item',
#  'dua',
#  'lemot',
#  "'",
#  'ujan',
#  'bertanggung',
#  'ups',
#  'konfirmasi',
#  'rp',
#  'terlambat',
#  'pasang',
#  'untung',
#  'or',
#  'go-food',
#  'blokir',
#  'berikan',
#  '-_-',
#  'merayap',
#  'smpai',
#  'gara2',
#  'urgent',
#  'limit',
#  '24',
#  'loading',
#  '100',
#  'fiktif',
#  'mengalami',
#  'set',
#  'ngisi',
#  'kondisi',
#  'sekitar',
#  'profil',
#  'muter2',
#  'sakit',
#  'rezeki',
#  'dokumen',
#  'rasa',
#  'ditinggal',
#  'ah',
#  'ikut',
#  'ngorder',
#  'istri',
#  'giliran',
#  'berguna',
#  'otak',
#  'abis',
#  'abang',
#  'loh',
#  'sini',
#  'q',
#  '10k',
#  '2x',
#  'woy',
#  'ttp',
#  'kebijakan',
#  'gada',
#  'php',
#  'mengapa',
#  'tambahan',
#  'mengantar',
#  'nyesel',
#  'bingung',
#  'kacau',
#  'diberikan',
#  'dipersulit',
#  'laporan',
#  'belom',
#  'membayar',
#  'rupiah',
#  'komplain',
#  'kepotong',
#  'gtu',
#  'mata',
#  'sperti',
#  'puas',
#  '20k',
#  'makanannya',
#  'barusan',
#  'knpa',
#  'klu',
#  'masuk2',
#  'batalkan',
#  'dasar',
#  'meskipun',
#  'marah',
#  'walau',
#  'seluruh',
#  'perusahaan',
#  'bapak',
#  '65rb',
#  'suatu',
#  'service',
#  'misi',
#  'bakal',
#  'info',
#  'gunanya',
#  'turunin',
#  'goblok',
#  'yaa',
#  'normal',
#  'mengeluh',
#  'ampun',
#  'voc',
#  'ditingkatkan',
#  'bnyk',
#  'wajar',
#  'aman',
#  'bukannya',
#  'inget',
#  'pembagian',
#  'selamat',
#  'daripada',
#  'pula',
#  'dikirim',
#  'ulasan',
#  'kedepan',
#  'dibekukan',
#  'berhenti',
#  'bohong',
#  'ditolak',
#  'ibu',
#  'gaada',
#  'aplikator',
#  'kenyamanan',
#  'tampilan',
#  'se',
#  'lgi',
#  'menjemput',
#  'dibuat',
#  'seenaknya',
#  'bawah',
#  'digital',
#  'ngapain',
#  'bodoh',
#  'pd',
#  'sekian',
#  'bakalan',
#  'sambil',
#  'aq',
#  'sehat',
#  'macam',
#  'asli',
#  'ditambah',
#  'gag',
#  'fokus',
#  'kualitas',
#  'rata',
#  'soal',
#  'senilai',
#  'bila',
#  'mendingan',
#  'ingat',
#  'duduk',
#  'jaringan',
#  'entah',
#  'peduli',
#  'grabfood',
#  'stiap',
#  ...]

# %%
w2v.vectors
# Out:
# array([[ 0.03834431,  0.19737446,  1.5746331 , ..., -0.24893184,
#         -1.2714243 ,  0.7045421 ],
#        [ 0.47159183,  0.9920001 ,  1.8186547 , ..., -1.5711766 ,
#         -1.3462093 , -0.5467184 ],
#        [-0.23808195,  1.6348968 , -0.1357832 , ...,  0.2739658 ,
#         -2.1487014 , -0.45402798],
#        ...,
#        [-1.1425531 , -0.8045286 ,  0.11660334, ..., -2.1053054 ,
#         -2.9483645 ,  1.7326711 ],
#        [ 2.4282458 ,  1.7900873 , -0.81434923, ...,  1.2435498 ,
#         -1.6615396 ,  1.6834487 ],
#        [ 1.4906496 , -1.6972607 , -0.62908584, ..., -1.2329481 ,
#         -0.6993661 , -0.7414474 ]], dtype=float32)

# %%
w2v.vector_size
# Out:
# 128

# %%
w2v['sepertinya']
# Out:
# array([ 0.76833177,  1.1094381 ,  0.133505  , -1.1274123 ,  1.9300805 ,
#        -0.78012   ,  0.05615833, -0.79901135,  3.0788934 ,  0.8870458 ,
#         0.79384387, -3.2046099 , -1.7834723 , -1.8499963 ,  0.24075627,
#         3.2859387 ,  1.3676164 ,  1.9708302 , -0.2314091 , -3.029348  ,
#        -0.38174322, -3.0621772 , -1.4423974 ,  3.7645247 ,  2.737375  ,
#        -0.5082192 , -2.7026832 , -0.93534434,  1.590301  ,  2.9525247 ,
#         3.4516602 , -2.4428782 , -1.1483067 , -0.18216507, -0.35854962,
#        -1.814619  , -0.46979484,  0.470524  , -0.25099593, -0.68367624,
#        -1.2579013 ,  1.4763334 ,  1.9010266 , -3.9073598 ,  1.2268602 ,
#         1.6215059 , -0.7460377 , -2.5657167 ,  0.80725026,  0.7474756 ,
#        -0.04583569,  2.7801256 ,  0.19732949,  1.1312993 , -0.7957213 ,
#         1.9160415 ,  4.6669    , -1.8121775 , -2.436151  , -1.2830954 ,
#        -0.3760371 , -1.2716372 , -2.244738  ,  0.11568068, -0.739354  ,
#         2.7568247 ,  0.2985564 , -0.8226016 ,  1.348325  , -0.58770883,
#         0.86689603, -0.913071  ,  0.3731277 , -1.4085883 ,  2.737222  ,
#        -2.6001148 , -1.6919369 ,  1.1382067 ,  3.1731265 ,  2.076632  ,
#        -1.2568212 , -0.32111678, -0.46434906, -1.4004441 ,  2.370969  ,
#        -0.52067703,  0.04109475, -0.29421934, -1.3213469 ,  0.4973115 ,
#         4.2035594 , -1.0549413 ,  3.5382614 , -2.2531762 ,  1.7112206 ,
#         1.4255714 , -1.5841782 , -1.5237486 ,  0.13428226, -2.1469057 ,
#         0.710077  , -1.6333009 ,  4.370305  ,  0.7014752 , -0.24342884,
#        -0.5631349 , -1.7306712 , -0.7159321 , -1.6777581 ,  0.40290427,
#        -1.3147292 , -3.2271304 ,  2.1318145 ,  1.578275  ,  1.9870396 ,
#         3.2946634 ,  1.2172221 ,  2.603801  ,  1.1932492 ,  1.3460528 ,
#         2.9216335 , -3.5258937 ,  2.0821707 ,  1.6650717 ,  0.34663996,
#         1.1888981 ,  0.0493695 , -0.98799485], dtype=float32)
